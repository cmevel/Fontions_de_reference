# %% [markdown]
# # La fonction inverse

# %% [markdown]
# **1. Une fonction donnant l'inverse d'un nombre**

# %%
def fctinverse(x):
    if x != 0:
        return (1/x)

# %% [markdown]
# **2. Tester-la avec plusieurs valeurs**

# %%
fctinverse(2)
# Out:
# 0.5

# %% [markdown]
# **3. Traçons la courbe représentative de la fonction inverse**

# %%
from pylab import *

x=linspace (-5,5,100)  #Tableau d'une ligne nommé x qui stocke les 100 valeurs équitablement réparties entre -5 et 5
y=fctinverse(x)        #Tableau des ordonnées

xlim(-5,5)             # Xmin et Xmax du graphique
ylim(-25,25)           # Ymin et Ymax du graphique

plot(x,y,"o")          # Liste des points rond non reliés 

title ('Courbe représentative de la fonction inverse') # Titre du graphique
xlabel('Abscisses')      #Titre de l'axe horizontal
ylabel('Ordonnées')      #Titre de l'axe vertical

grid()                 # Quadrillage

show()                 # Affichage du tracé des points

# %% [markdown]
# **4. Améliorons le tracé**

# %%
from pylab import *

x=linspace (-5,5,100)  #Tableau d'une ligne nommé x qui stocke les 100 valeurs équitablement réparties entre -5 et 5
y=fctinverse(x)        #Tableau des ordonnées

xlim(-5,5)             # Xmin et Xmax du graphique
ylim(-25,25)           # Ymin et Ymax du graphique

plot(x,y,'r')          # Liste des points reliés en rouge 

title ('Courbe représentative de la fonction inverse') # Titre du graphique
xlabel('Abscisses')      #Titre de l'axe horizontal
ylabel('Ordonnées')      #Titre de l'axe vertical

grid()                 # Quadrillage

show()                 # Affichage du tracé des points

# %% [markdown]
# **Oups, il y a un problème !**

# %% [markdown]
# **5. Supprimons cette fameuse valeur x=0 et voyons le résultat**

# %%
from pylab import *

x1=linspace (-5,0,100) #Tableau d'une ligne nommé x1 qui stocke les 100 valeurs équitablement réparties entre -5 et 5
x2=linspace(0,5,100)

y1=fctinverse(x1)        #Tableaux des ordonnées
y2=fctinverse(x2)

xlim(-5,5)             # Xmin et Xmax du graphique
ylim(-25,25)           # Ymin et Ymax du graphique

plot(x1,y1)          # Liste des points rond non reliés 
plot(x2,y2)

title ('Courbe représentative de la fonction inverse') # Titre du graphique
xlabel('Abscisses')      #Titre de l'axe horizontal
ylabel('Ordonnées')      #Titre de l'axe vertical

grid()                 # Quadrillage

show()                 # Affichage du tracé des points
# Out:
# /Users/christophe_mevel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide

# %% [markdown]
# **Oups, il y a toujours un problème**

# %% [markdown]
# **6. Traçons donc en s'approchant le plus possible de 0**

# %%
from pylab import *

x1=linspace (-5,-0.01,100) #Tableau d'une ligne nommé x1 qui stocke les 100 valeurs équitablement réparties entre -5 et 5
x2=linspace(0.01,5,100)

y1=fctinverse(x1)        #Tableaux des ordonnées
y2=fctinverse(x2)

xlim(-5,5)             # Xmin et Xmax du graphique
ylim(-25,25)           # Ymin et Ymax du graphique

plot(x1,y1)          # Liste des points rond non reliés 
plot(x2,y2)

title ('Courbe représentative de la fonction inverse') # Titre du graphique
xlabel('Abscisses')      #Titre de l'axe horizontal
ylabel('Ordonnées')      #Titre de l'axe vertical

grid()                 # Quadrillage

show()                 # Affichage du tracé des points

# %% [markdown]
# **7. Modifier le dernier programme pour s'approcher davantage de la valeur 0. (Augmenter aussi les valeurs dans Ylim pour voir le résultat)**
